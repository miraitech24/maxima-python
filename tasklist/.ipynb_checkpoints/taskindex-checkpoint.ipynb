# %%
import json
import pandas as pd
from IPython.display import display, HTML, FileLink
from pathlib import Path

with open("habitable_index.json") as f:
    data = json.load(f)

parts = data["parts"]

print("📂 章一覧（クリックでファイルを開く）")
print("-" * 50)

for title, filename in parts.items():
    if Path(filename).exists():
        link = FileLink(filename)
        print(f"📁 {title}")
        display(link)
        print()
    else:
        print(f"⚠️ {title}: {filename} が見つかりません")
# Out:
# 📂 章一覧（クリックでファイルを開く）
# --------------------------------------------------
# 📁 第1章_エウロパ・ハック（生産基盤）
# /home/iwamura/ドキュメント/coupling/working/interstellar(skip)/interstellar/interstellar1.json
# 📁 第2章_資源収奪・運送（木星圏運用）
# /home/iwamura/ドキュメント/coupling/working/interstellar(skip)/interstellar/interstellar2.json
# 📁 テザー列車
# /home/iwamura/ドキュメント/coupling/working/interstellar(skip)/interstellar/tether.json
# 📁 He3搬送
# /home/iwamura/ドキュメント/coupling/working/interstellar(skip)/interstellar/He3.json
