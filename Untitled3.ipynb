# %%
load("~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac");
# Out:
# (%o7)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac

# %%
display
