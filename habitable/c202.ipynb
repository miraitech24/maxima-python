# %%
load("~/ドキュメント/coupling/working/habitable/c202.mac");
# Out:
# ===== c202: 量子ビット集積化 - 光子損失確率 =====
# --- 基本パラメータ ---
# NVセンター発光波長: 637. nm
# 発光寿命: 13. ns
# 量子収率: 80.0%
# ナノダイヤモンド直径: 100. nm
# ダイヤモンド屈折率: 2.40
# 導波路長: 1. mm
# 導波路損失: 3.0 dB/cm
# 検出器量子効率: 90.0%
# 集光NA: 0.50
# --- 光子損失計算 ---
# 損失要因の内訳:
#   1. ナノダイヤモンド吸収: 1.0000 (0.00%)
#   2. 表面フレネル反射: 0.8304 (16.96%)
#   3. 放射パターン集光: 0.0670 (93.30%)
#   4. 導波路結合: 0.7000 (30.00%)
#   5. 導波路伝搬: 0.9333 (6.67%)
#   6. 検出器効率: 0.9000 (10.00%)
# 全透過率: 0.0327 (3.27%)
# 全損失確率: 0.9673 (96.73%)
# --- パラメータスイープ ---
# ナノダイヤモンド直径 [nm] | 全透過率 | 損失確率
# ------------------------+---------+---------
#        50.          |  0.0327  |  0.9673
#       100.          |  0.0327  |  0.9673
#       150.          |  0.0327  |  0.9673
#       200.          |  0.0327  |  0.9673
#       250.          |  0.0327  |  0.9673
#       300.          |  0.0327  |  0.9673
# 導波路長 [mm] | 全透過率 | 損失確率
# -------------+---------+---------
#      0.1       |  0.0348  |  0.9652
#      0.6       |  0.0336  |  0.9664
# ...
