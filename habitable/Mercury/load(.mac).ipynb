# %%
load("~/ドキュメント/maxima/mac_files/solution_線形代数_上級_0022.mac");
# Out:
#                              2
# ev: improper argument: lambda  - 1
#  -- an error. To debug this try: debugmode(true);
# MAXIMA-ERROR: ~:M: improper argument: ~M
