# %%
stardisp: true;
# Out:
# (%o17)                               true

# %%
batch("~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac");
# Out:
# read and interpret /home/iwamura/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac
# ((MLABEL) $%I21
#  ((MSETQ (71 "~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac" SRC))
#   $STARDISP T))
# ((MLABEL) $%O21 T)
# ((MLABEL) $%I22
#  ((MSETQ (71 "~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac" SRC))
#   $DISPLAY2D T))
# ((MLABEL) $%O22 T)
# ((MLABEL) $%I23
#  ((MSETQ (71 "~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac" SRC))
#   $MATRIXDISPLAY T))
# ((MLABEL) $%O23 T)
# ((MLABEL) $%I24
#  ((MSETQ (71 "~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac" SRC)) $LINEL
#   1000))
# ((MLABEL) $%O24 1000)
# ((MLABEL) $%I25
#  (($VARIANCE (72 "~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac" SRC))
#   ((MLIST (72 "~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac" SRC)) 1 2 3
#    4 5)))
# ((MLABEL) $%O25
#  (($VARIANCE SIMP
#    (72 "~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac" SRC))
#   ((MLIST SIMP (72 "~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac" SRC)) 1
# ...

# %%
load("~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac");
# Out:
# (%o26)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac

# %%
display(%);
# Out:
# ((MLABEL) NIL
#  ((MEQUAL SIMP) $% "~/ドキュメント/maxima/mac_files/solution_確率統計_初級_017.mac"))
# (%o27)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            done
